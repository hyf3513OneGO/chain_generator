# %%
from rdkit import Chem
from rdkit.Chem import rdMolAlign
import os

def get_all_task_dirs(results_dir="results"):
    task_dirs = []
    for prefix in os.listdir(results_dir):
        prefix_path = os.path.join(results_dir, prefix)
        if not os.path.isdir(prefix_path):
            continue
        for task_id in os.listdir(prefix_path):
            task_path = os.path.join(prefix_path, task_id)
            if os.path.isdir(task_path):
                task_dirs.append(task_path)
    return task_dirs

def calc_rmsd_for_task(task_dir):
    init_path = os.path.join(task_dir, "homopoly_init.sdf")
    relaxed_path = os.path.join(task_dir, "homopoly_relaxed.sdf")
    if not (os.path.exists(init_path) and os.path.exists(relaxed_path)):
        return None
    mol_init = Chem.SDMolSupplier(init_path, removeHs=False)[0]
    mol_relaxed = Chem.SDMolSupplier(relaxed_path, removeHs=False)[0]
    if mol_init is None or mol_relaxed is None:
        return None
    # 保证分子有构象
    if mol_init.GetNumConformers() == 0 or mol_relaxed.GetNumConformers() == 0:
        return None
    # 计算RMSD
    try:
        rmsd = rdMolAlign.GetBestRMS(mol_init, mol_relaxed)
    except Exception as e:
        rmsd = None
    return rmsd

results = []
task_dirs = get_all_task_dirs("results")
for task_dir in task_dirs:
    rmsd = calc_rmsd_for_task(task_dir)
    if rmsd is not None:
        print(f"{task_dir}: RMSD = {rmsd:.4f}")
        results.append((task_dir, rmsd))
    else:
        print(f"{task_dir}: 计算失败或文件缺失")
# Out:
# results/test/task_78_repeat-5-monomers: RMSD = 0.7454
# results/test/task_20_repeat-5-monomers: RMSD = 0.0081
# results/test/task_99_repeat-5-monomers: RMSD = 1.1993
# results/test/task_105_repeat-5-monomers: RMSD = 0.0992
# results/test/task_75_repeat-5-monomers: RMSD = 0.2254
# results/test/task_58_repeat-5-monomers: RMSD = 0.0000
# results/test/task_13_repeat-5-monomers: RMSD = 0.1164
# results/test/task_6_repeat-5-monomers: RMSD = 0.7257
# results/test/task_52_repeat-5-monomers: RMSD = 1.0339
# results/test/task_12_repeat-5-monomers: RMSD = 0.3298
# results/test/task_98_repeat-5-monomers: RMSD = 0.0474
# results/test/task_27_repeat-5-monomers: RMSD = 0.1601
# results/test/task_53_repeat-5-monomers: RMSD = 0.0098
# results/test/task_40_repeat-5-monomers: RMSD = 1.0578
# results/test/task_38_repeat-5-monomers: RMSD = 0.4574
# results/test/task_59_repeat-5-monomers: RMSD = 1.9150
# results/test/task_29_repeat-5-monomers: RMSD = 0.6817
# results/test/task_5_repeat-5-monomers: RMSD = 0.4146
# results/test/task_25_repeat-5-monomers: RMSD = 0.0000
# results/test/task_11_repeat-5-monomers: RMSD = 0.1980
# results/test/task_57_repeat-5-monomers: RMSD = 1.2705
# results/test/task_22_repeat-5-monomers: RMSD = 0.3227
# results/test/task_74_repeat-5-monomers: RMSD = 0.1288
# results/test/task_46_repeat-5-monomers: RMSD = 0.0383
# results/test/task_44_repeat-5-monomers: RMSD = 0.1235
# results/test/task_65_repeat-5-monomers: RMSD = 0.8399
# results/test/task_103_repeat-5-monomers: RMSD = 1.0367
# results/test/task_88_repeat-5-monomers: RMSD = 1.2449
# results/test/task_7_repeat-5-monomers: RMSD = 0.0790
# results/test/task_18_repeat-5-monomers: RMSD = 1.2738
# results/test/task_45_repeat-5-monomers: RMSD = 0.7817
# results/test/task_42_repeat-5-monomers: RMSD = 0.1973
# results/test/task_41_repeat-5-monomers: RMSD = 0.5534
# results/test/task_8_repeat-5-monomers: RMSD = 0.3440
# results/test/task_4_repeat-5-monomers: RMSD = 0.3249
# results/test/task_24_repeat-5-monomers: RMSD = 0.3491
# results/test/task_21_repeat-5-monomers: RMSD = 0.3449
# results/test/task_9_repeat-5-monomers: RMSD = 0.2943
# results/test/task_69_repeat-5-monomers: RMSD = 1.4515
# results/test/task_32_repeat-5-monomers: RMSD = 1.1482
# results/test/task_62_repeat-5-monomers: RMSD = 0.4739
# results/test/task_68_repeat-5-monomers: RMSD = 0.1847
# results/test/task_51_repeat-5-monomers: RMSD = 1.6635
# results/test/task_82_repeat-5-monomers: RMSD = 0.1319
# results/test/task_54_repeat-5-monomers: RMSD = 0.2715
# results/test/task_66_repeat-5-monomers: RMSD = 0.2061
# results/test/task_17_repeat-5-monomers: RMSD = 0.0383
# results/test/task_49_repeat-5-monomers: RMSD = 0.9998
# results/test/task_10_repeat-5-monomers: RMSD = 0.8931
# results/test/task_83_repeat-5-monomers: RMSD = 1.4875
# results/test/task_19_repeat-5-monomers: RMSD = 1.1400
# results/test/task_91_repeat-5-monomers: RMSD = 1.7707
# results/test/task_48_repeat-5-monomers: RMSD = 1.3853
# results/test/task_37_repeat-5-monomers: RMSD = 0.1889
# results/test/task_0_repeat-5-monomers: RMSD = 1.1946
# results/test/task_55_repeat-5-monomers: RMSD = 1.4248
# results/test/task_61_repeat-5-monomers: RMSD = 1.4916
# results/test/task_79_repeat-5-monomers: RMSD = 0.0928
# results/test/task_92_repeat-5-monomers: RMSD = 0.8345
# results/test/task_86_repeat-5-monomers: RMSD = 1.1311
# results/test/task_31_repeat-5-monomers: RMSD = 2.5148
# results/test/task_14_repeat-5-monomers: RMSD = 0.5679
# results/test/task_96_repeat-5-monomers: RMSD = 0.9685
# results/test/task_16_repeat-5-monomers: RMSD = 0.1441
# results/test/task_34_repeat-5-monomers: RMSD = 3.1907
# results/test/task_28_repeat-5-monomers: RMSD = 0.1512
# results/test/task_72_repeat-5-monomers: RMSD = 0.3262
# results/test/task_76_repeat-5-monomers: RMSD = 0.9035
# results/test/task_89_repeat-5-monomers: RMSD = 0.0192
# results/test/task_67_repeat-5-monomers: RMSD = 0.2250
# results/test/task_47_repeat-5-monomers: RMSD = 1.0017
# results/test/task_81_repeat-5-monomers: RMSD = 0.6880
# results/test/task_3_repeat-5-monomers: RMSD = 0.3496
# results/test/task_100_repeat-5-monomers: RMSD = 0.0052
# results/test/task_73_repeat-5-monomers: RMSD = 0.9499
# results/test/task_104_repeat-5-monomers: RMSD = 1.0244
# results/test/task_94_repeat-5-monomers: RMSD = 0.0533
# results/test/task_90_repeat-5-monomers: RMSD = 0.7714
# results/test/task_33_repeat-5-monomers: RMSD = 0.0086
# results/test/task_63_repeat-5-monomers: RMSD = 0.3136
# results/test/task_1_repeat-5-monomers: RMSD = 0.4161
# results/test/task_26_repeat-5-monomers: RMSD = 0.7457
# results/test/task_60_repeat-5-monomers: RMSD = 3.4922
# results/test/task_64_repeat-5-monomers: RMSD = 0.2103
# results/test/task_95_repeat-5-monomers: RMSD = 0.1638
# results/test/task_80_repeat-5-monomers: RMSD = 0.3309
# results/test/task_70_repeat-5-monomers: RMSD = 0.6657
# results/test/task_50_repeat-5-monomers: RMSD = 0.5022
# results/test/task_109_repeat-5-monomers: RMSD = 0.7664
# results/test/task_36_repeat-5-monomers: RMSD = 0.5891
# results/test/task_30_repeat-5-monomers: RMSD = 1.2893
# results/test/task_2_repeat-5-monomers: RMSD = 0.7457
# results/test/task_43_repeat-5-monomers: RMSD = 0.3091
# results/test/task_77_repeat-5-monomers: RMSD = 0.0193
# results/test/task_93_repeat-5-monomers: RMSD = 0.8324

# %%
import numpy as np

def calc_local_monomer_rmsd(task_dir):
    """
    计算task_dir下所有local_monomer_x.sdf之间的两两RMSD，返回一个RMSD矩阵和单体文件名列表
    """
    # 找到所有local_monomer_*.sdf文件
    monomer_files = []
    for fname in os.listdir(task_dir):
        if fname.startswith("local_monomer_") and fname.endswith(".sdf"):
            monomer_files.append(fname)
    monomer_files.sort()  # 按序号排序

    if len(monomer_files) < 2:
        print(f"{task_dir}: local_monomer数量不足2，无法计算RMSD")
        return None, None

    # 读取所有分子
    monomers = []
    for f in monomer_files:
        mol = Chem.SDMolSupplier(os.path.join(task_dir, f), removeHs=False)[0]
        if mol is None or mol.GetNumConformers() == 0:
            print(f"{task_dir}: {f} 读取失败或无构象")
            return None, None
        monomers.append(mol)

    n = len(monomers)
    rmsd_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(i+1, n):
            try:
                rmsd = rdMolAlign.GetBestRMS(monomers[i], monomers[j])
            except Exception as e:
                print(e)
                rmsd = np.nan
            rmsd_matrix[i, j] = rmsd
            rmsd_matrix[j, i] = rmsd
    return rmsd_matrix, monomer_files

# 对每个任务文件夹计算local_monomer的RMSD矩阵
for task_dir in task_dirs:
    rmsd_matrix, monomer_files = calc_local_monomer_rmsd(task_dir)
    if rmsd_matrix is not None:
        print(f"\n{task_dir} 的 local_monomer 两两RMSD矩阵：")
        print("单体文件顺序：", monomer_files)
        print(np.array_str(rmsd_matrix, precision=4, suppress_small=True))
    else:
        print(f"{task_dir}: local_monomer RMSD计算失败")
# Out:
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_78_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.6355 0.6651 0.5921    nan]
#  [0.6355 0.     0.1211 0.1918    nan]
#  [0.6651 0.1211 0.     0.2333    nan]
#  [0.5921 0.1918 0.2333 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_20_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     1.7841 0.8548 1.0861]
#  [   nan 1.7841 0.     1.4421 1.0231]
#  [   nan 0.8548 1.4421 0.     0.7864]
#  [   nan 1.0861 1.0231 0.7864 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_99_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.
repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.0684 0.065  0.0627 0.054 ]
#  [0.0684 0.     0.0373 0.0278 0.055 ]
#  [0.065  0.0373 0.     0.0117 0.0453]
#  [0.0627 0.0278 0.0117 0.     0.0411]
#  [0.054  0.055  0.0453 0.0411 0.    ]]
#
# results/test/task_81_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.5189 0.1354 0.6131 0.6545]
#  [0.5189 0.     0.5644 0.1931 0.255 ]
#  [0.1354 0.5644 0.     0.6666 0.71  ]
#  [0.6131 0.1931 0.6666 0.     0.0746]
#  [0.6545 0.255  0.71   0.0746 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_3_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.2865 0.0566 0.256 ]
#  [   nan 0.2865 0.     0.3167 0.0528]
#  [   nan 0.0566 0.3167 0.     0.2843]
#  [   nan 0.256  0.0528 0.2843 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_100_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.6942 0.683  0.6817    nan]
#  [0.6942 0.     0.1182 0.0967    nan]
#  [0.683  0.1182 0.     0.1438    nan]
#  [0.6817 0.0967 0.1438 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
#
# results/test/task_73_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     1.2651 1.1883 1.196  0.1916]
#  [1.2651 0.     0.4144 0.4555 1.2916]
#  [1.1883 0.4144 0.     0.3091 1.2054]
#  [1.196  0.4555 0.3091 0.     1.2186]
#  [0.1916 1.2916 1.2054 1.2186 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_104_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.775  0.664     nan]
#  [   nan 0.775  0.     0.1752    nan]
#  [   nan 0.664  0.1752 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
#
# results/test/task_94_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.041  0.6809 0.0526 0.6629]
#  [0.041  0.     0.6888 0.019  0.6729]
#  [0.6809 0.6888 0.     0.6944 0.0515]
#  [0.0526 0.019  0.6944 0.     0.6788]
#  [0.6629 0.6729 0.0515 0.6788 0.    ]]
#
# results/test/task_90_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.9705 1.3343 1.1378 1.2924]
#  [0.9705 0.     1.4652 1.2663 0.78  ]
#  [1.3343 1.4652 0.     0.5604 1.1739]
#  [1.1378 1.2663 0.5604 0.     0.9925]
#  [1.2924 0.78   1.1739 0.9925 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_33_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.5133 0.5133 0.5057]
#  [   nan 0.5133 0.     0.0544 0.0845]
#  [   nan 0.5133 0.0544 0.     0.0399]
#  [   nan 0.5057 0.0845 0.0399 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_63_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.8303 0.0458 0.7197]
#  [   nan 0.8303 0.     0.8381 0.258 ]
#  [   nan 0.0458 0.8381 0.     0.7245]
#  [   nan 0.7197 0.258  0.7245 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_1_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.7482 0.7359 0.4252]
#  [   nan 0.7482 0.     0.0258 0.6304]
#  [   nan 0.7359 0.0258 0.     0.6182]
#  [   nan 0.4252 0.6304 0.6182 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_26_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.1576 0.0735 0.211 ]
#  [   nan 0.1576 0.     0.224  0.0735]
#  [   nan 0.0735 0.224  0.     0.2695]
#  [   nan 0.211  0.0735 0.2695 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_60_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.7775 1.2102 1.1741    nan]
#  [0.7775 0.     1.1517 1.1583    nan]
#  [1.2102 1.1517 0.     0.8881    nan]
#  [1.1741 1.1583 0.8881 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_64_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.2177 1.0539 1.0538]
#  [   nan 0.2177 0.     1.0635 1.0627]
#  [   nan 1.0539 1.0635 0.     0.0193]
#  [   nan 1.0538 1.0627 0.0193 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_95_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.9406 0.9445 0.0379]
#  [   nan 0.9406 0.     0.0661 0.9462]
#  [   nan 0.9445 0.0661 0.     0.95  ]
#  [   nan 0.0379 0.9462 0.95   0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_80_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     1.1194 1.3049 1.3011]
#  [   nan 1.1194 0.     1.3509 1.4027]
#  [   nan 1.3049 1.3509 0.     0.1021]
#  [   nan 1.3011 1.4027 0.1021 0.    ]]
#
# results/test/task_70_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.0474 0.5084 0.5073 0.3096]
#  [0.0474 0.     0.4973 0.4981 0.3194]
#  [0.5084 0.4973 0.     0.0956 0.5855]
#  [0.5073 0.4981 0.0956 0.     0.5977]
#  [0.3096 0.3194 0.5855 0.5977 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_50_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.6128 0.6001 0.5855    nan]
#  [0.6128 0.     0.036  0.3783    nan]
#  [0.6001 0.036  0.     0.388     nan]
#  [0.5855 0.3783 0.388  0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
#
# results/test/task_109_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.5753 0.5061 0.5996 0.1026]
#  [0.5753 0.     0.786  0.73   0.4942]
#  [0.5061 0.786  0.     0.1843 0.554 ]
#  [0.5996 0.73   0.1843 0.     0.6254]
#  [0.1026 0.4942 0.554  0.6254 0.    ]]
#
# results/test/task_36_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.5216 0.1066 0.5738 0.081 ]
#  [0.5216 0.     0.5468 0.3328 0.5256]
#  [0.1066 0.5468 0.     0.5991 0.1198]
#  [0.5738 0.3328 0.5991 0.     0.5718]
#  [0.081  0.5256 0.1198 0.5718 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_30_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     1.478  0.3627 0.4264    nan]
#  [1.478  0.     1.4213 1.3247    nan]
#  [0.3627 1.4213 0.     0.5171    nan]
#  [0.4264 1.3247 0.5171 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_2_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.9177 0.6913 0.8229]
#  [   nan 0.9177 0.     0.909  1.2112]
#  [   nan 0.6913 0.909  0.     0.6557]
#  [   nan 0.8229 1.2112 0.6557 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_43_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     0.0921 0.056     nan]
#  [   nan 0.0921 0.     0.0907    nan]
#  [   nan 0.056  0.0907 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_77_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.     0.053  0.1104 0.0858    nan]
#  [0.053  0.     0.1202 0.09      nan]
#  [0.1104 0.1202 0.     0.0869    nan]
#  [0.0858 0.09   0.0869 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
# No sub-structure match found between the reference and probe mol
#
# results/test/task_93_repeat-5-monomers 的 local_monomer 两两RMSD矩阵：
# 单体文件顺序： ['local_monomer_0.sdf', 'local_monomer_1.sdf', 'local_monomer_2.sdf', 'local_monomer_3.sdf', 'local_monomer_4.sdf']
# [[0.        nan    nan    nan    nan]
#  [   nan 0.     1.1913 0.1416    nan]
#  [   nan 1.1913 0.     1.0905    nan]
#  [   nan 0.1416 1.0905 0.        nan]
#  [   nan    nan    nan    nan 0.    ]]
