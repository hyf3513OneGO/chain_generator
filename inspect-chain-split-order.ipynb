# %%
import glob
import os
import rdkit.Chem as Chem
import numpy as np
task_dirs = sorted(glob.glob("results/mini/task_*_repeat-5-monomers"))
local_monomers_all = []
global_monomers_all = []
R_list_all = []
t_list_all = []
psmiles_all = []
global_chain_all = []
for task_dir in task_dirs:
    local_monomer_sdf_files = sorted(glob.glob(os.path.join(task_dir, "local_monomer_*.sdf")))
    local_monomer_mols = [Chem.MolFromMolFile(path) for path in local_monomer_sdf_files]
    local_monomers_all.append(local_monomer_mols)
    global_monomer_sdf_files = sorted(glob.glob(os.path.join(task_dir, "global_monomer_*.sdf")))
    global_monomer_mols = [Chem.MolFromMolFile(path) for path in global_monomer_sdf_files]
    global_monomers_all.append(global_monomer_mols)
    global_chain = Chem.MolFromMolFile(os.path.join(task_dir,"homopoly_relaxed.sdf"))
    global_chain_all.append(global_chain)
    R_list = np.load(os.path.join(task_dir,"R_list.npy"))
    t_list = np.load(os.path.join(task_dir,"t_list.npy"))
    R_list_all.append(R_list)
    t_list_all.append(t_list)
    psmiles = ""
    with open(os.path.join(task_dir,"psmiles.txt"),"r") as f:
        psmiles = f.read()
    psmiles_all.append(psmiles)

# %%
from utils.chain_split_utils import remove_star_atoms
for idx in range(len(local_monomers_all)):
    key_point_list, processed_mol, processed_smi = remove_star_atoms(psmiles)
    local_monomers = local_monomers_all[idx]
    global_monomers = global_monomers_all[idx]
    global_chain = global_chain_all[idx]
    R_list = R_list_all[idx]
    t_list = t_list_all[idx]
    psmiles = psmiles_all[idx]
    for j in range(len(local_monomers)):
        mol_from_smi = Chem.MolFromSmiles(processed_smi)
        local_monomer = local_monomers[j]
        global_monomer = global_monomers[j]
        # 判断两个分子的原子顺序是否一致
        def is_atom_order_same(mol1, mol2):
            """
            判断两个分子的原子顺序是否一致。
            这里只比较原子类型顺序，不比较坐标。
            """
            if mol1.GetNumAtoms() != mol2.GetNumAtoms():
                return False
            atom_types1 = [atom.GetSymbol() for atom in mol1.GetAtoms()]
            atom_types2 = [atom.GetSymbol() for atom in mol2.GetAtoms()]
            return atom_types1 == atom_types2

        atom_order_same1 = is_atom_order_same(local_monomer, global_monomer)
        atom_order_same2 = is_atom_order_same(mol_from_smi, global_monomer)
        atom_order_same3 = is_atom_order_same(mol_from_smi, local_monomer)
        print(f"task {idx}, monomer {j} 原子顺序一致: {atom_order_same1}, {atom_order_same2}, {atom_order_same3}")
# Out:
# task 0, monomer 0 原子顺序一致: True, False, False
# task 0, monomer 1 原子顺序一致: True, False, False
# task 0, monomer 2 原子顺序一致: True, False, False
# task 0, monomer 3 原子顺序一致: True, False, False
# task 0, monomer 4 原子顺序一致: True, False, False
# task 1, monomer 0 原子顺序一致: True, False, False
# task 1, monomer 1 原子顺序一致: True, False, False
# task 1, monomer 2 原子顺序一致: True, False, False
# task 1, monomer 3 原子顺序一致: True, False, False
# task 1, monomer 4 原子顺序一致: True, False, False
# task 2, monomer 0 原子顺序一致: True, False, False
# task 2, monomer 1 原子顺序一致: True, False, False
# task 2, monomer 2 原子顺序一致: True, False, False
# task 2, monomer 3 原子顺序一致: True, False, False
# task 2, monomer 4 原子顺序一致: True, False, False
# task 3, monomer 0 原子顺序一致: True, False, False
# task 3, monomer 1 原子顺序一致: True, False, False
# task 3, monomer 2 原子顺序一致: True, False, False
# task 3, monomer 3 原子顺序一致: True, False, False
# task 3, monomer 4 原子顺序一致: True, False, False
# task 4, monomer 0 原子顺序一致: True, False, False
# task 4, monomer 1 原子顺序一致: True, False, False
# task 4, monomer 2 原子顺序一致: True, False, False
# task 4, monomer 3 原子顺序一致: True, False, False
# task 4, monomer 4 原子顺序一致: True, False, False
# task 5, monomer 0 原子顺序一致: True, False, False
# task 5, monomer 1 原子顺序一致: True, False, False
# task 5, monomer 2 原子顺序一致: True, False, False
# task 5, monomer 3 原子顺序一致: True, False, False
# task 5, monomer 4 原子顺序一致: True, False, False
# task 6, monomer 0 原子顺序一致: True, False, False
# task 6, monomer 1 原子顺序一致: True, False, False
# task 6, monomer 2 原子顺序一致: True, False, False
# task 6, monomer 3 原子顺序一致: True, False, False
# task 6, monomer 4 原子顺序一致: True, False, False
# task 7, monomer 0 原子顺序一致: True, False, False
# task 7, monomer 1 原子顺序一致: True, False, False
# task 7, monomer 2 原子顺序一致: True, False, False
# task 7, monomer 3 原子顺序一致: True, False, False
# task 7, monomer 4 原子顺序一致: True, False, False
# task 8, monomer 0 原子顺序一致: True, False, False
# task 8, monomer 1 原子顺序一致: True, False, False
# task 8, monomer 2 原子顺序一致: True, False, False
# task 8, monomer 3 原子顺序一致: True, False, False
# task 8, monomer 4 原子顺序一致: True, False, False
# task 9, monomer 0 原子顺序一致: True, False, False
# task 9, monomer 1 原子顺序一致: True, False, False
# task 9, monomer 2 原子顺序一致: True, False, False
# task 9, monomer 3 原子顺序一致: True, False, False
# task 9, monomer 4 原子顺序一致: True, False, False
# task 10, monomer 0 原子顺序一致: True, False, False
# task 10, monomer 1 原子顺序一致: True, False, False
# task 10, monomer 2 原子顺序一致: True, False, False
# task 10, monomer 3 原子顺序一致: True, False, False
# task 10, monomer 4 原子顺序一致: True, False, False
# task 11, monomer 0 原子顺序一致: True, False, False
# task 11, monomer 1 原子顺序一致: True, False, False
# task 11, monomer 2 原子顺序一致: True, False, False
# task 11, monomer 3 原子顺序一致: True, False, False
# task 11, monomer 4 原子顺序一致: True, False, False
# task 12, monomer 0 原子顺序一致: True, False, False
# task 12, monomer 1 原子顺序一致: True, False, False
# task 12, monomer 2 原子顺序一致: True, False, False
# task 12, monomer 3 原子顺序一致: True, False, False
# task 12, monomer 4 原子顺序一致: True, False, False
# task 13, monomer 0 原子顺序一致: True, False, False
# task 13, monomer 1 原子顺序一致: True, False, False
# task 13, monomer 2 原子顺序一致: True, False, False
# task 13, monomer 3 原子顺序一致: True, False, False
# task 13, monomer 4 原子顺序一致: True, False, False
# task 14, monomer 0 原子顺序一致: True, False, False
# task 14, monomer 1 原子顺序一致: True, False, False
# task 14, monomer 2 原子顺序一致: True, False, False
# task 14, monomer 3 原子顺序一致: True, False, False
# task 14, monomer 4 原子顺序一致: True, False, False
# task 15, monomer 0 原子顺序一致: True, False, False
# task 15, monomer 1 原子顺序一致: True, False, False
# task 15, monomer 2 原子顺序一致: True, False, False
# task 15, monomer 3 原子顺序一致: True, False, False
# task 15, monomer 4 原子顺序一致: True, False, False
# task 16, monomer 0 原子顺序一致: True, False, False
# task 16, monomer 1 原子顺序一致: True, False, False
# task 16, monomer 2 原子顺序一致: True, False, False
# task 16, monomer 3 原子顺序一致: True, False, False
# task 16, monomer 4 原子顺序一致: True, False, False
# task 17, monomer 0 原子顺序一致: True, False, False
# task 17, monomer 1 原子顺序一致: True, False, False
# task 17, monomer 2 原子顺序一致: True, False, False
# task 17, monomer 3 原子顺序一致: True, False, False
# task 17, monomer 4 原子顺序一致: True, False, False
# task 18, monomer 0 原子顺序一致: True, False, False
# task 18, monomer 1 原子顺序一致: True, False, False
# task 18, monomer 2 原子顺序一致: True, False, False
# task 18, monomer 3 原子顺序一致: True, False, False
# task 18, monomer 4 原子顺序一致: True, False, False
# task 19, monomer 0 原子顺序一致: True, False, False
# task 19, monomer 1 原子顺序一致: True, False, False
# task 19, monomer 2 原子顺序一致: True, False, False
# task 19, monomer 3 原子顺序一致: True, False, False
# task 19, monomer 4 原子顺序一致: True, False, False
# task 20, monomer 0 原子顺序一致: True, False, False
# task 20, monomer 1 原子顺序一致: True, False, False
# task 20, monomer 2 原子顺序一致: True, False, False
# task 20, monomer 3 原子顺序一致: True, False, False
# task 20, monomer 4 原子顺序一致: True, False, False
# task 21, monomer 0 原子顺序一致: True, False, False
# task 21, monomer 1 原子顺序一致: True, False, False
# task 21, monomer 2 原子顺序一致: True, False, False
# task 21, monomer 3 原子顺序一致: True, False, False
# task 21, monomer 4 原子顺序一致: True, False, False
# task 22, monomer 0 原子顺序一致: True, False, False
# task 22, monomer 1 原子顺序一致: True, False, False
# task 22, monomer 2 原子顺序一致: True, False, False
# task 22, monomer 3 原子顺序一致: True, False, False
# task 22, monomer 4 原子顺序一致: True, False, False
# task 23, monomer 0 原子顺序一致: True, False, False
# task 23, monomer 1 原子顺序一致: True, False, False
# task 23, monomer 2 原子顺序一致: True, False, False
# task 23, monomer 3 原子顺序一致: True, False, False
# task 23, monomer 4 原子顺序一致: True, False, False
# task 24, monomer 0 原子顺序一致: True, False, False
# task 24, monomer 1 原子顺序一致: True, False, False
# task 24, monomer 2 原子顺序一致: True, False, False
# task 24, monomer 3 原子顺序一致: True, False, False
# task 24, monomer 4 原子顺序一致: True, False, False
# task 25, monomer 0 原子顺序一致: True, False, False
# task 25, monomer 1 原子顺序一致: True, False, False
# task 25, monomer 2 原子顺序一致: True, False, False
# task 25, monomer 3 原子顺序一致: True, False, False
# task 25, monomer 4 原子顺序一致: True, False, False
# task 26, monomer 0 原子顺序一致: True, False, False
# task 26, monomer 1 原子顺序一致: True, False, False
# task 26, monomer 2 原子顺序一致: True, False, False
# task 26, monomer 3 原子顺序一致: True, False, False
# task 26, monomer 4 原子顺序一致: True, False, False
# task 27, monomer 0 原子顺序一致: True, False, False
# task 27, monomer 1 原子顺序一致: True, False, False
# task 27, monomer 2 原子顺序一致: True, False, False
# task 27, monomer 3 原子顺序一致: True, False, False
# task 27, monomer 4 原子顺序一致: True, False, False
# task 28, monomer 0 原子顺序一致: True, False, False
# task 28, monomer 1 原子顺序一致: True, False, False
# task 28, monomer 2 原子顺序一致: True, False, False
# task 28, monomer 3 原子顺序一致: True, False, False
# task 28, monomer 4 原子顺序一致: True, False, False
# task 29, monomer 0 原子顺序一致: True, False, False
# task 29, monomer 1 原子顺序一致: True, False, False
# task 29, monomer 2 原子顺序一致: True, False, False
# task 29, monomer 3 原子顺序一致: True, False, False
# task 29, monomer 4 原子顺序一致: True, False, False
# task 30, monomer 0 原子顺序一致: True, False, False
# task 30, monomer 1 原子顺序一致: True, False, False
# task 30, monomer 2 原子顺序一致: True, False, False
# task 30, monomer 3 原子顺序一致: True, False, False
# task 30, monomer 4 原子顺序一致: True, False, False
# task 31, monomer 0 原子顺序一致: True, False, False
# task 31, monomer 1 原子顺序一致: True, False, False
# task 31, monomer 2 原子顺序一致: True, False, False
# task 31, monomer 3 原子顺序一致: True, False, False
# task 31, monomer 4 原子顺序一致: True, False, False
# task 32, monomer 0 原子顺序一致: True, False, False
# task 32, monomer 1 原子顺序一致: True, False, False
# task 32, monomer 2 原子顺序一致: True, False, False
# task 32, monomer 3 原子顺序一致: True, False, False
# task 32, monomer 4 原子顺序一致: True, False, False
# task 33, monomer 0 原子顺序一致: True, False, False
# task 33, monomer 1 原子顺序一致: True, False, False
# task 33, monomer 2 原子顺序一致: True, False, False
# task 33, monomer 3 原子顺序一致: True, False, False
# task 33, monomer 4 原子顺序一致: True, False, False
# task 34, monomer 0 原子顺序一致: True, False, False
# task 34, monomer 1 原子顺序一致: True, False, False
# task 34, monomer 2 原子顺序一致: True, False, False
# task 34, monomer 3 原子顺序一致: True, False, False
# task 34, monomer 4 原子顺序一致: True, False, False
# task 35, monomer 0 原子顺序一致: True, False, False
# task 35, monomer 1 原子顺序一致: True, False, False
# task 35, monomer 2 原子顺序一致: True, False, False
# task 35, monomer 3 原子顺序一致: True, False, False
# task 35, monomer 4 原子顺序一致: True, False, False
# task 36, monomer 0 原子顺序一致: True, False, False
# task 36, monomer 1 原子顺序一致: True, False, False
# task 36, monomer 2 原子顺序一致: True, False, False
# task 36, monomer 3 原子顺序一致: True, False, False
# task 36, monomer 4 原子顺序一致: True, False, False
# task 37, monomer 0 原子顺序一致: True, False, False
# task 37, monomer 1 原子顺序一致: True, False, False
# task 37, monomer 2 原子顺序一致: True, False, False
# task 37, monomer 3 原子顺序一致: True, False, False
# task 37, monomer 4 原子顺序一致: True, False, False
# task 38, monomer 0 原子顺序一致: True, False, False
# task 38, monomer 1 原子顺序一致: True, False, False
# task 38, monomer 2 原子顺序一致: True, False, False
# task 38, monomer 3 原子顺序一致: True, False, False
# task 38, monomer 4 原子顺序一致: True, False, False
# task 39, monomer 0 原子顺序一致: True, False, False
# task 39, monomer 1 原子顺序一致: True, False, False
# task 39, monomer 2 原子顺序一致: True, False, False
# task 39, monomer 3 原子顺序一致: True, False, False
# task 39, monomer 4 原子顺序一致: True, False, False
# task 40, monomer 0 原子顺序一致: True, False, False
# task 40, monomer 1 原子顺序一致: True, False, False
# task 40, monomer 2 原子顺序一致: True, False, False
# task 40, monomer 3 原子顺序一致: True, False, False
# task 40, monomer 4 原子顺序一致: True, False, False
# task 41, monomer 0 原子顺序一致: True, False, False
# task 41, monomer 1 原子顺序一致: True, False, False
# task 41, monomer 2 原子顺序一致: True, False, False
# task 41, monomer 3 原子顺序一致: True, False, False
# task 41, monomer 4 原子顺序一致: True, False, False
# task 42, monomer 0 原子顺序一致: True, False, False
# task 42, monomer 1 原子顺序一致: True, False, False
# task 42, monomer 2 原子顺序一致: True, False, False
# task 42, monomer 3 原子顺序一致: True, False, False
# task 42, monomer 4 原子顺序一致: True, False, False
# task 43, monomer 0 原子顺序一致: True, False, False
# task 43, monomer 1 原子顺序一致: True, False, False
# task 43, monomer 2 原子顺序一致: True, False, False
# task 43, monomer 3 原子顺序一致: True, False, False
# task 43, monomer 4 原子顺序一致: True, False, False
# task 44, monomer 0 原子顺序一致: True, False, False
# task 44, monomer 1 原子顺序一致: True, False, False
# task 44, monomer 2 原子顺序一致: True, False, False
# task 44, monomer 3 原子顺序一致: True, False, False
# task 44, monomer 4 原子顺序一致: True, False, False
# task 45, monomer 0 原子顺序一致: True, False, False
# task 45, monomer 1 原子顺序一致: True, False, False
# task 45, monomer 2 原子顺序一致: True, False, False
# task 45, monomer 3 原子顺序一致: True, False, False
# task 45, monomer 4 原子顺序一致: True, False, False
# task 46, monomer 0 原子顺序一致: True, False, False
# task 46, monomer 1 原子顺序一致: True, False, False
# task 46, monomer 2 原子顺序一致: True, False, False
# task 46, monomer 3 原子顺序一致: True, False, False
# task 46, monomer 4 原子顺序一致: True, False, False
# task 47, monomer 0 原子顺序一致: True, False, False
# task 47, monomer 1 原子顺序一致: True, False, False
# task 47, monomer 2 原子顺序一致: True, False, False
# task 47, monomer 3 原子顺序一致: True, False, False
# task 47, monomer 4 原子顺序一致: True, False, False
# task 48, monomer 0 原子顺序一致: True, False, False
# task 48, monomer 1 原子顺序一致: True, False, False
# task 48, monomer 2 原子顺序一致: True, False, False
# task 48, monomer 3 原子顺序一致: True, False, False
# task 48, monomer 4 原子顺序一致: True, False, False
# task 49, monomer 0 原子顺序一致: True, False, False
# task 49, monomer 1 原子顺序一致: True, False, False
# task 49, monomer 2 原子顺序一致: True, False, False
# task 49, monomer 3 原子顺序一致: True, False, False
# task 49, monomer 4 原子顺序一致: True, False, False
# task 50, monomer 0 原子顺序一致: True, False, False
# task 50, monomer 1 原子顺序一致: True, False, False
# task 50, monomer 2 原子顺序一致: True, False, False
# task 50, monomer 3 原子顺序一致: True, False, False
# task 50, monomer 4 原子顺序一致: True, False, False
# task 51, monomer 0 原子顺序一致: True, False, False
# task 51, monomer 1 原子顺序一致: True, False, False
# task 51, monomer 2 原子顺序一致: True, False, False
# task 51, monomer 3 原子顺序一致: True, False, False
# task 51, monomer 4 原子顺序一致: True, False, False
# task 52, monomer 0 原子顺序一致: True, False, False
# task 52, monomer 1 原子顺序一致: True, False, False
# task 52, monomer 2 原子顺序一致: True, False, False
# task 52, monomer 3 原子顺序一致: True, False, False
# task 52, monomer 4 原子顺序一致: True, False, False
# task 53, monomer 0 原子顺序一致: True, False, False
# task 53, monomer 1 原子顺序一致: True, False, False
# task 53, monomer 2 原子顺序一致: True, False, False
# task 53, monomer 3 原子顺序一致: True, False, False
# task 53, monomer 4 原子顺序一致: True, False, False
# task 54, monomer 0 原子顺序一致: True, False, False
# task 54, monomer 1 原子顺序一致: True, False, False
# task 54, monomer 2 原子顺序一致: True, False, False
# task 54, monomer 3 原子顺序一致: True, False, False
# task 54, monomer 4 原子顺序一致: True, False, False
# task 55, monomer 0 原子顺序一致: True, False, False
# task 55, monomer 1 原子顺序一致: True, False, False
# task 55, monomer 2 原子顺序一致: True, False, False
# task 55, monomer 3 原子顺序一致: True, False, False
# task 55, monomer 4 原子顺序一致: True, False, False
# task 56, monomer 0 原子顺序一致: True, False, False
# task 56, monomer 1 原子顺序一致: True, False, False
# task 56, monomer 2 原子顺序一致: True, False, False
# task 56, monomer 3 原子顺序一致: True, False, False
# task 56, monomer 4 原子顺序一致: True, False, False
# task 57, monomer 0 原子顺序一致: True, False, False
# task 57, monomer 1 原子顺序一致: True, False, False
# task 57, monomer 2 原子顺序一致: True, False, False
# task 57, monomer 3 原子顺序一致: True, False, False
# task 57, monomer 4 原子顺序一致: True, False, False
# task 58, monomer 0 原子顺序一致: True, False, False
# task 58, monomer 1 原子顺序一致: True, False, False
# task 58, monomer 2 原子顺序一致: True, False, False
# task 58, monomer 3 原子顺序一致: True, False, False
# task 58, monomer 4 原子顺序一致: True, False, False
# task 59, monomer 0 原子顺序一致: True, False, False
# task 59, monomer 1 原子顺序一致: True, False, False
# task 59, monomer 2 原子顺序一致: True, False, False
# task 59, monomer 3 原子顺序一致: True, False, False
# task 59, monomer 4 原子顺序一致: True, False, False
# task 60, monomer 0 原子顺序一致: True, False, False
# task 60, monomer 1 原子顺序一致: True, False, False
# task 60, monomer 2 原子顺序一致: True, False, False
# task 60, monomer 3 原子顺序一致: True, False, False
# task 60, monomer 4 原子顺序一致: True, False, False
# task 61, monomer 0 原子顺序一致: True, False, False
# task 61, monomer 1 原子顺序一致: True, False, False
# task 61, monomer 2 原子顺序一致: True, False, False
# task 61, monomer 3 原子顺序一致: True, False, False
# task 61, monomer 4 原子顺序一致: True, False, False
# task 62, monomer 0 原子顺序一致: True, False, False
# task 62, monomer 1 原子顺序一致: True, False, False
# task 62, monomer 2 原子顺序一致: True, False, False
# task 62, monomer 3 原子顺序一致: True, False, False
# task 62, monomer 4 原子顺序一致: True, False, False
# task 63, monomer 0 原子顺序一致: True, False, False
# task 63, monomer 1 原子顺序一致: True, False, False
# task 63, monomer 2 原子顺序一致: True, False, False
# task 63, monomer 3 原子顺序一致: True, False, False
# task 63, monomer 4 原子顺序一致: True, False, False
# task 64, monomer 0 原子顺序一致: True, False, False
# task 64, monomer 1 原子顺序一致: True, False, False
# task 64, monomer 2 原子顺序一致: True, False, False
# task 64, monomer 3 原子顺序一致: True, False, False
# task 64, monomer 4 原子顺序一致: True, False, False
# task 65, monomer 0 原子顺序一致: True, False, False
# task 65, monomer 1 原子顺序一致: True, False, False
# task 65, monomer 2 原子顺序一致: True, False, False
# task 65, monomer 3 原子顺序一致: True, False, False
# task 65, monomer 4 原子顺序一致: True, False, False
# task 66, monomer 0 原子顺序一致: True, False, False
# task 66, monomer 1 原子顺序一致: True, False, False
# task 66, monomer 2 原子顺序一致: True, False, False
# task 66, monomer 3 原子顺序一致: True, False, False
# task 66, monomer 4 原子顺序一致: True, False, False
# task 67, monomer 0 原子顺序一致: True, False, False
# task 67, monomer 1 原子顺序一致: True, False, False
# task 67, monomer 2 原子顺序一致: True, False, False
# task 67, monomer 3 原子顺序一致: True, False, False
# task 67, monomer 4 原子顺序一致: True, False, False
# task 68, monomer 0 原子顺序一致: True, False, False
# task 68, monomer 1 原子顺序一致: True, False, False
# task 68, monomer 2 原子顺序一致: True, False, False
# task 68, monomer 3 原子顺序一致: True, False, False
# task 68, monomer 4 原子顺序一致: True, False, False
# task 69, monomer 0 原子顺序一致: True, False, False
# task 69, monomer 1 原子顺序一致: True, False, False
# task 69, monomer 2 原子顺序一致: True, False, False
# task 69, monomer 3 原子顺序一致: True, False, False
# task 69, monomer 4 原子顺序一致: True, False, False
# task 70, monomer 0 原子顺序一致: True, False, False
# task 70, monomer 1 原子顺序一致: True, False, False
# task 70, monomer 2 原子顺序一致: True, False, False
# task 70, monomer 3 原子顺序一致: True, False, False
# task 70, monomer 4 原子顺序一致: True, False, False
# task 71, monomer 0 原子顺序一致: True, False, False
# task 71, monomer 1 原子顺序一致: True, False, False
# task 71, monomer 2 原子顺序一致: True, False, False
# task 71, monomer 3 原子顺序一致: True, False, False
# task 71, monomer 4 原子顺序一致: True, False, False
# task 72, monomer 0 原子顺序一致: True, False, False
# task 72, monomer 1 原子顺序一致: True, False, False
# task 72, monomer 2 原子顺序一致: True, False, False
# task 72, monomer 3 原子顺序一致: True, False, False
# task 72, monomer 4 原子顺序一致: True, False, False
# task 73, monomer 0 原子顺序一致: True, False, False
# task 73, monomer 1 原子顺序一致: True, False, False
# task 73, monomer 2 原子顺序一致: True, False, False
# task 73, monomer 3 原子顺序一致: True, False, False
# task 73, monomer 4 原子顺序一致: True, False, False
# task 74, monomer 0 原子顺序一致: True, False, False
# task 74, monomer 1 原子顺序一致: True, False, False
# task 74, monomer 2 原子顺序一致: True, False, False
# task 74, monomer 3 原子顺序一致: True, False, False
# task 74, monomer 4 原子顺序一致: True, False, False
# task 75, monomer 0 原子顺序一致: True, False, False
# task 75, monomer 1 原子顺序一致: True, False, False
# task 75, monomer 2 原子顺序一致: True, False, False
# task 75, monomer 3 原子顺序一致: True, False, False
# task 75, monomer 4 原子顺序一致: True, False, False
# task 76, monomer 0 原子顺序一致: True, False, False
# task 76, monomer 1 原子顺序一致: True, False, False
# task 76, monomer 2 原子顺序一致: True, False, False
# task 76, monomer 3 原子顺序一致: True, False, False
# task 76, monomer 4 原子顺序一致: True, False, False
# task 77, monomer 0 原子顺序一致: True, False, False
# task 77, monomer 1 原子顺序一致: True, False, False
# task 77, monomer 2 原子顺序一致: True, False, False
# task 77, monomer 3 原子顺序一致: True, False, False
# task 77, monomer 4 原子顺序一致: True, False, False
# task 78, monomer 0 原子顺序一致: True, False, False
# task 78, monomer 1 原子顺序一致: True, False, False
# task 78, monomer 2 原子顺序一致: True, False, False
# task 78, monomer 3 原子顺序一致: True, False, False
# task 78, monomer 4 原子顺序一致: True, False, False
# task 79, monomer 0 原子顺序一致: True, False, False
# task 79, monomer 1 原子顺序一致: True, False, False
# task 79, monomer 2 原子顺序一致: True, False, False
# task 79, monomer 3 原子顺序一致: True, False, False
# task 79, monomer 4 原子顺序一致: True, False, False
# task 80, monomer 0 原子顺序一致: True, False, False
# task 80, monomer 1 原子顺序一致: True, False, False
# task 80, monomer 2 原子顺序一致: True, False, False
# task 80, monomer 3 原子顺序一致: True, False, False
# task 80, monomer 4 原子顺序一致: True, False, False
# task 81, monomer 0 原子顺序一致: True, False, False
# task 81, monomer 1 原子顺序一致: True, False, False
# task 81, monomer 2 原子顺序一致: True, False, False
# task 81, monomer 3 原子顺序一致: True, False, False
# task 81, monomer 4 原子顺序一致: True, False, False
# task 82, monomer 0 原子顺序一致: True, False, False
# task 82, monomer 1 原子顺序一致: True, False, False
# task 82, monomer 2 原子顺序一致: True, False, False
# task 82, monomer 3 原子顺序一致: True, False, False
# task 82, monomer 4 原子顺序一致: True, False, False
# task 83, monomer 0 原子顺序一致: True, False, False
# task 83, monomer 1 原子顺序一致: True, False, False
# task 83, monomer 2 原子顺序一致: True, False, False
# task 83, monomer 3 原子顺序一致: True, False, False
# task 83, monomer 4 原子顺序一致: True, False, False
# task 84, monomer 0 原子顺序一致: True, False, False
# task 84, monomer 1 原子顺序一致: True, False, False
# task 84, monomer 2 原子顺序一致: True, False, False
# task 84, monomer 3 原子顺序一致: True, False, False
# task 84, monomer 4 原子顺序一致: True, False, False
# task 85, monomer 0 原子顺序一致: True, False, False
# task 85, monomer 1 原子顺序一致: True, False, False
# task 85, monomer 2 原子顺序一致: True, False, False
# task 85, monomer 3 原子顺序一致: True, False, False
# task 85, monomer 4 原子顺序一致: True, False, False
# task 86, monomer 0 原子顺序一致: True, False, False
# task 86, monomer 1 原子顺序一致: True, False, False
# task 86, monomer 2 原子顺序一致: True, False, False
# task 86, monomer 3 原子顺序一致: True, False, False
# task 86, monomer 4 原子顺序一致: True, False, False
# task 87, monomer 0 原子顺序一致: True, False, False
# task 87, monomer 1 原子顺序一致: True, False, False
# task 87, monomer 2 原子顺序一致: True, False, False
# task 87, monomer 3 原子顺序一致: True, False, False
# task 87, monomer 4 原子顺序一致: True, False, False
# task 88, monomer 0 原子顺序一致: True, False, False
# task 88, monomer 1 原子顺序一致: True, False, False
# task 88, monomer 2 原子顺序一致: True, False, False
# task 88, monomer 3 原子顺序一致: True, False, False
# task 88, monomer 4 原子顺序一致: True, False, False
# task 89, monomer 0 原子顺序一致: True, False, False
# task 89, monomer 1 原子顺序一致: True, False, False
# task 89, monomer 2 原子顺序一致: True, False, False
# task 89, monomer 3 原子顺序一致: True, False, False
# task 89, monomer 4 原子顺序一致: True, False, False
# task 90, monomer 0 原子顺序一致: True, False, False
# task 90, monomer 1 原子顺序一致: True, False, False
# task 90, monomer 2 原子顺序一致: True, False, False
# task 90, monomer 3 原子顺序一致: True, False, False
# task 90, monomer 4 原子顺序一致: True, False, False
# task 91, monomer 0 原子顺序一致: True, False, False
# task 91, monomer 1 原子顺序一致: True, False, False
# task 91, monomer 2 原子顺序一致: True, False, False
# task 91, monomer 3 原子顺序一致: True, False, False
# task 91, monomer 4 原子顺序一致: True, False, False
# task 92, monomer 0 原子顺序一致: True, False, False
# task 92, monomer 1 原子顺序一致: True, False, False
# task 92, monomer 2 原子顺序一致: True, False, False
# task 92, monomer 3 原子顺序一致: True, False, False
# task 92, monomer 4 原子顺序一致: True, False, False
